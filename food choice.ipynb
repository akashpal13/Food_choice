# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read file
df = pd.read_csv(r'C:\Users\ASUS\Downloads\archive\food_coded.csv',encoding= 'unicode_escape')

# %%
df.shape
# Out:
# (125, 61)

# %%
# top five value
df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %%
# Top head value
df.head(10)
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
# 5   2.25       1          1               610           3.0           980.0
# 6    3.8       2          1               610           3.0           420.0
# 7    3.3       1          1               720           3.0           420.0
# 8    3.3       1          1               430           NaN           420.0
# 9    3.3       1          1               430           3.0           315.0
#
#    coffee                                  comfort_food  \
# 0       1                                          none
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          123 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
df.head(10)
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
# 5   2.25       1          1               610           3.0           980.0
# 6    3.8       2          1               610           3.0           420.0
# 7    3.3       1          1               720           3.0           420.0
# 8    3.3       1          1               430           NaN           420.0
# 9    3.3       1          1               430           3.0           315.0
#
#    coffee                                  comfort_food  \
# 0       1                                          none
# ...

# %%
# Delete sports
df.drop(['sports'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          123 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
pd.isnull(df)
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    False   False      False             False          True           False
# 1    False   False      False             False         False           False
# 2    False   False      False             False         False           False
# 3    False   False      False             False         False           False
# 4    False   False      False             False         False           False
# ..     ...     ...        ...               ...           ...             ...
# 120  False   False      False             False         False           False
# 121  False   False      False             False         False           False
# 122  False   False      False             False          True           False
# 123  False   False      False             False         False           False
# 124  False   False      False             False          True           False
#
# ...

# %%
df.drop(['employment','father_education','father_profession','income','marital_status','mother_education'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 54 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          123 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
pd.isnull(df)
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    False   False      False             False          True           False
# 1    False   False      False             False         False           False
# 2    False   False      False             False         False           False
# 3    False   False      False             False         False           False
# 4    False   False      False             False         False           False
# ..     ...     ...        ...               ...           ...             ...
# 120  False   False      False             False         False           False
# 121  False   False      False             False         False           False
# 122  False   False      False             False          True           False
# 123  False   False      False             False         False           False
# 124  False   False      False             False          True           False
#
# ...

# %%
df.drop(['type_sports'],axis=1,inplace=True)

# %%
pd.isnull(df)
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    False   False      False             False          True           False
# 1    False   False      False             False         False           False
# 2    False   False      False             False         False           False
# 3    False   False      False             False         False           False
# 4    False   False      False             False         False           False
# ..     ...     ...        ...               ...           ...             ...
# 120  False   False      False             False         False           False
# 121  False   False      False             False         False           False
# 122  False   False      False             False          True           False
# 123  False   False      False             False         False           False
# 124  False   False      False             False          True           False
#
# ...

# %%
pd.isnull(df).sum()
# Out:
# GPA                              2
# Gender                           0
# breakfast                        0
# calories_chicken                 0
# calories_day                    19
# calories_scone                   1
# coffee                           0
# comfort_food                     1
# comfort_food_reasons             2
# comfort_food_reasons_coded      19
# cook                             3
# comfort_food_reasons_coded.1     0
# cuisine                         17
# diet_current                     1
# diet_current_coded               0
# drink                            2
# eating_changes                   3
# eating_changes_coded             0
# eating_changes_coded1            0
# eating_out                       0
# ethnic_food                      0
# exercise                        13
# fav_cuisine                      2
# fav_cuisine_coded                0
# fav_food                         2
# food_childhood                   1
# fries                            0
# ...

# %%
# check for null value
pd.isnull(df).sum()
# Out:
# GPA                              2
# Gender                           0
# breakfast                        0
# calories_chicken                 0
# calories_day                    19
# calories_scone                   1
# coffee                           0
# comfort_food                     1
# comfort_food_reasons             2
# comfort_food_reasons_coded      19
# cook                             3
# comfort_food_reasons_coded.1     0
# cuisine                         17
# diet_current                     1
# diet_current_coded               0
# drink                            2
# eating_changes                   3
# eating_changes_coded             0
# eating_changes_coded1            0
# eating_out                       0
# ethnic_food                      0
# exercise                        13
# fav_cuisine                      2
# fav_cuisine_coded                0
# fav_food                         2
# food_childhood                   1
# fries                            0
# ...

# %%
df.shape
# Out:
# (125, 53)

# %%
# Drop null value
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (64, 53)

# %%
# initialize list of list
data_test=[['Shinu',11], ['Shraddha',12], ['Akash',13], ['Sandip', ]]

# create the pandas DataFrame using list
df_test=pd.DataFrame(data_test,columns=['Name','Age'])

df_test
# Out:
#        Name   Age
# 0     Shinu  11.0
# 1  Shraddha  12.0
# 2     Akash  13.0
# 3    Sandip   NaN

# %%
# df_test.dropna() unsaved
df_test.dropna(inplace=True) 
# if dont wnat to write inplace
# kuch bhi=df_test.dropna() but not good

# %%
df_test
# Out:
#        Name   Age
# 0     Shinu  11.0
# 1  Shraddha  12.0
# 2     Akash  13.0

# %%
# Both are same thing
# df.test.dropna(inplace=True)
# df.test=df_test.dropna()

# %%
df['vitamins']=df['vitamins'].astype('float')

# %%
df['vitamins'].dtypes
# Out:
# dtype('float64')

# %%
df.columns
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_chicken', 'calories_day',
#        'calories_scone', 'coffee', 'comfort_food', 'comfort_food_reasons',
#        'comfort_food_reasons_coded', 'cook', 'comfort_food_reasons_coded.1',
#        'cuisine', 'diet_current', 'diet_current_coded', 'drink',
#        'eating_changes', 'eating_changes_coded', 'eating_changes_coded1',
#        'eating_out', 'ethnic_food', 'exercise', 'fav_cuisine',
#        'fav_cuisine_coded', 'fav_food', 'food_childhood', 'fries', 'fruit_day',
#        'grade_level', 'greek_food', 'healthy_feeling', 'healthy_meal',
#        'ideal_diet', 'ideal_diet_coded', 'indian_food', 'italian_food',
#        'life_rewarding', 'meals_dinner_friend', 'mother_profession',
#        'nutritional_check', 'on_off_campus', 'parents_cook', 'pay_meal_out',
#        'persian_food', 'self_perception_weight', 'soup', 'thai_food',
#        'tortilla_calories', 'turkey_calories', 'veggies_day', 'vitamins',
# ...

# %%
# rename
# this is called key:value pair dic
df.rename(columns={'coffee':'Chai'})
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# 6      3.8       2          1               610           3.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 91     3.8       1          2               610           2.0           420.0
# 96    3.92       2          1               430           3.0           420.0
# 97     3.9       1          1               720           3.0           420.0
# 103    3.7       1          1               610           3.0           420.0
# 105      3       1          1               720           3.0           420.0
#
# ...

# %%
# describe() method returns description of the data in the dataframe
df.describe()
# Out:
#           Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# count  64.000000  64.000000         64.000000     64.000000       64.000000
# mean    1.406250   1.109375        603.750000      3.046875      516.796875
# std     0.495015   0.314576        111.941737      0.602368      226.030914
# min     1.000000   1.000000        265.000000      2.000000      315.000000
# 25%     1.000000   1.000000        610.000000      3.000000      420.000000
# 50%     1.000000   1.000000        610.000000      3.000000      420.000000
# 75%     2.000000   1.000000        720.000000      3.000000      420.000000
# max     2.000000   2.000000        720.000000      4.000000      980.000000
#
#           coffee  comfort_food_reasons_coded       cook  \
# count  64.000000                   64.000000  64.000000
# mean    1.765625                    2.406250   2.671875
# std     0.426956                    1.761301   1.127642
# min     1.000000                    1.000000   1.000000
# ...

# %%
# use describe() for specific coloumns
df[['Gender','coffee','calories_chicken']].describe()
# Out:
#           Gender     coffee  calories_chicken
# count  64.000000  64.000000         64.000000
# mean    1.406250   1.765625        603.750000
# std     0.495015   0.426956        111.941737
# min     1.000000   1.000000        265.000000
# 25%     1.000000   2.000000        610.000000
# 50%     1.000000   2.000000        610.000000
# 75%     2.000000   2.000000        720.000000
# max     2.000000   2.000000        720.000000

# %%
# EDA(Exploratory data Analysis

# %%
df.coloumns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15736\2425176728.py in ?()
# ----> 1 df.coloumns
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'coloumns'

# %%
df.columns
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_chicken', 'calories_day',
#        'calories_scone', 'coffee', 'comfort_food', 'comfort_food_reasons',
#        'comfort_food_reasons_coded', 'cook', 'comfort_food_reasons_coded.1',
#        'cuisine', 'diet_current', 'diet_current_coded', 'drink',
#        'eating_changes', 'eating_changes_coded', 'eating_changes_coded1',
#        'eating_out', 'ethnic_food', 'exercise', 'fav_cuisine',
#        'fav_cuisine_coded', 'fav_food', 'food_childhood', 'fries', 'fruit_day',
#        'grade_level', 'greek_food', 'healthy_feeling', 'healthy_meal',
#        'ideal_diet', 'ideal_diet_coded', 'indian_food', 'italian_food',
#        'life_rewarding', 'meals_dinner_friend', 'mother_profession',
#        'nutritional_check', 'on_off_campus', 'parents_cook', 'pay_meal_out',
#        'persian_food', 'self_perception_weight', 'soup', 'thai_food',
#        'tortilla_calories', 'turkey_calories', 'veggies_day', 'vitamins',
# ...

# %%
sns.countplot(x='Gender', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
ax=sns.countplot(x='Gender', data=df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.groupby(['Gender'], as_index=False)['calories_day'].sum().sort_values(by='calories_day', ascending=False)
# Out:
#    Gender  calories_day
# 0       1         116.0
# 1       2          79.0

# %%
sales_gen=df.groupby(['Gender'], as_index=False)['calories_day'].sum().sort_values(by='calories_day', ascending=False)

sns.barplot(x='Gender', y='calories_day', data=sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='calories_day'>
